# %% [markdown]
# # scoutvec — vecinos por coseno
#
# Solo para **mirar** resultados. La produccion vive en modulos:
# `python -m scoutvec.vectors`, `python -m scoutvec.similarity`.

# %%
from scoutvec.similarity import show

# %%
show("Messi")
show("Busquets")
show("Piqué")

# %%
show("Messi", role="W")
show("Busquets", role="DM")
show("Piqué", role="CB")
